# %% [markdown]
# <h1><center> PPOL 5203 Data Science I: Foundations <br><br>
# <font color='grey'>Problem Set I<br><br>
# Tiago Ventura</center></center> <h1>

# %% [markdown]
# This problem set will focus on:
#
# - Best Practices for project organization, reproducibility and coding
# - Git: working with branches, mergins, and solving conflict
# - Git: understanding commit structure.
#
# Your deadline for submission is Friday, september 23, until midnight.
#
# You should submit via github classroom.
#
# I will consider your last commit as your final submission.

# %% [markdown]
# ## Question 1 (pts 30)
#
# Congratulations!! Your data science report was accepted for publication! As it has become the norm, you now have to submit the data and code for replication of your report's results.
#
# You decided to create a github repo with all the materials (data, code, figures) of your article. You article has the following materials:
#
# - `main.py` (runs the main results of the paper);
# - `res_sif.py` (runs all results of the appendix);
# - `ana_add_p.py` (additional analysis main paper);
# - `prep   II  version_3.py` (does all the processing of the data);
# - `survey s II qualtrics 12/10.csv` (raw data);
# - `raw_data_II_saved_by_coauthor_X.json` (clean data);
# - `fig.png` (figure 1)
# - `figure abs.png` (figure 2)
# - `figure abs2.png` (figure 3)
# - `figure abs3.png` (figure 4)
# - `figure abs4.png` (figure 5)
# - `figure sif.png` (figure 1 appendix with heteregenous effects)
# - `figure sif .png` (figure 2 appendix results for polarization)
# - `figure sif .png` (figure 3 appendix robustness checks)
#
# **Your taks:** Create a folder in this repository named `question-01` that follows the best practices for project management and reproducibility we discussed in class.
#
# - Tip 1: Check [this repo](https://github.com/TiagoVentura/winning_plosone/tree/main) to see what your response should look like.
#
# - Tip 2: Create a readme.md file explaining your repository, describing your article, folder, and all the files. The readme should be inside the main folder
#
# - Tip 3: All the files above have bad names. Rename them following best practices.
#
# - Tip 4: I do not care what is inside of each file. Just create a empty file/output with the appropiate name.
#
# - Tip 5: You **do not** need to worry about creating a conda or pyenv environment.
#
# To submit your homework,  indicate name of your folder in the repository.

# %%
# No needs to answer anything here. This should be a full folder in your repository

# %% [markdown]
# ## Question 2 (pts 30)
#
# 1. In your main repository (from github classroom), create a `.txt` named `solutions_for_question_2`. Write the name of your favorite book in the file.
#
# 2. Add that file to the staging area.
#
# 3. Commit that file with a clear commit message
#
# 4. Create and checkout a new branch called "wish_to"
#
# 5. Make a change `solutions_for_question_2` and commit. The change should be adding your second favorite book.
#
# 3. Switch back to the `master` or `main` branch.
#
# 4. Make a change `solutions_for_question_2` and commit. Add the book you want to read next. Make sure that change is to the same line as you change in step 5. Make sure the change differs from what you did in step two.
#
# 5. Now merge the `new` and `master` branches.
#
# 6. Manually resolve the git conflict and then commit the resolved version. Be detailed on how you are solving the conflict
#
# 7. Look at your git and describe with words the timeline of changes.

# %%
# Paste here all the commands you used to answer this questions. 
# Use instructive commit message, since we will look at those to grade your homework 

# Go to the file of problem set
cd PPOL_data
cd problem-set-01-annlsec

# create a .txt named solutions_for_question_2.
touch solutions_for_question_2.txt
git add solutions_for_question_2.txt

# Write the name of favorite book in the file
echo 'Harry Potter' > solutions_for_question_2.txt

# Add that file to the staging area.
git add solutions_for_question_2.txt


# Commit that file with a clear commit message
git commit -m 'the name of my favorite book'           


# Create and checkout a new branch called "wish_to"
git checkout -b wish_to

# adding second favorite book to solutions_for_question_2
echo 'Percy Jackson' >> solutions_for_question_2.txt
cat solutions_for_question_2.txt

# commit after changed
git add solutions_for_question_2.txt
git commit -m 'adding my second favorite book'


# Switch back to the main branch
git checkout main

# Make a change solutions_for_question_2 and commit. Add the book you want to read next.
echo 'Any book but text book' >> solutions_for_question_2.txt 
cat solutions_for_question_2.txt

# commit the change
git add solutions_for_question_2.txt
git commit -m 'the book I want to read next'



# merge the wish_to and main branches
git merge wish_to

# solve the conflict in solutions_for_question_2
vim solutions_for_question_2.txt

# commit the change
git add solutions_for_question_2.txt
git commit -m 'fixed conflict'

# Look at your git and describe with words the timeline of changes.
git log

# %% [markdown]
# #### Look at your git and describe with words the timeline of changes.
#
# Initially, I created a text file containing the name of my favorite book. Afterward, I branched out and edited the text file to include the name of my second favorite book. So, in the new branch, the text file now contained both my favorite book's name and the name of my second favorite book.
#
# Next, I returned to the main branch and edited the text file to add the book I wanted to read next. Consequently, the text file in the main branch now listed my favorite book's name along with the book I was eager to read.
#
# Subsequently, I merged the two branches together. The computer flagged a conflict in the text file since there were differing messages in the same location. To resolve this conflict, I re-edited the text file, moving the book I wanted to read to a different line. As a result, the conflict was successfully resolved, and the merge was completed without issues.

# %% [markdown]
# ## Question 3 (pts 40)
#
# Solve the challenges of this Git Scavenger task
#
# Here is the link of the task:
#
# https://github.com/PPOL-5203-2023/git-scavenger-hunt-20203
#
# Provide your answers below in this notebook.

# %% [markdown]
# #### What is the title of the news story?
#
# The title of the news story is "Trump is explaining exactly how wild and extreme his second term would be."
#
#
# #### What changes were made to the news story in a later commit?
#
# Several lines were deleted (line 4-7, 16-19, 22-24) and an url was added to the end of the news story.
#
#
# #### Which book I am currently reading?
# You are currently reading two books, "Babel, or the Necessity of Violence: An Arcane History of the Oxford Translators' Revolution" and "Ted Chiang: Exhalation."
#
#
# #### Which year did I read more books?
# You read most books in 2021
# 22 books in total.
#
#
# #### Have you read any of the books I read in the past years? What is your favorite?
# I have read Game of Thrones but I did not finish the whole series. My favorite books are Harry Potter.
#
#
# #### Why there are no information about the books in the main branch? Which commit did that happen?
#
# When you updated dog images, you also deleted the books information.
#
#
# #### How many branches are still active? What is their difference?
#
# Currently, there are two active branches: "main" and "what_i_have_been_reading." In the "what_i_have_been_reading" branch, you've retained information about the books. However, in the "main" branch, you've deleted the information about the books and made additional edits to the files through multiple commits.
#
#
# #### Which dog picture did you find more cute?
# All the dogs are cute! I love the third picture the most.
#
#
#
# #### What is the tag name for the commit where the readme was changed to how you read now?
#
# commit ID:
# b76269f
#
# message: find the tag again
